# %%
# CREATED: 22-JUN-2023
# LAST EDIT: 22-JUN-2023
# AUTHOR: DUANE RINEHART, MBA (drinehart@ucsd.edu)

#DANDI WIDGETS IS VISUALIZATION TOOL OF NWB FILES (LOCALY OR VIA API TO DANDI ARCHIVE)
#ref: https://github.com/NeurodataWithoutBorders/nwbwidgets


#FOLLOWING FOR ACCESSING DANDISET ON DANDIARCHIVE SITE:
from dandi.dandiapi import DandiAPIClient
client = DandiAPIClient()

#WANT TO VIEW - DANDI:000398/0.221208.1803
dandiset = client.get_dandiset("000398")
meta = dandiset.get_raw_metadata()
#print(meta)
# Out:
# A newer version (0.55.1) of dandi/dandi-cli is available. You are using 0.39.6
# {'id': 'DANDI:000398/0.221208.1803',
#  'doi': '10.48324/dandi.000398/0.221208.1803',
#  'url': 'https://dandiarchive.org/dandiset/000398/0.221208.1803',
#  'name': 'Scalable Thousand Channel Penetrating Microneedle Arrays on Flex for Multimodal and Large Area Coverage BrainMachine Interfaces',
#  'about': [],
#  'access': [{'status': 'dandi:OpenAccess', 'schemaKey': 'AccessRequirements'}],
#  'license': ['spdx:CC-BY-4.0'],
#  'version': '0.221208.1803',
#  '@context': 'https://raw.githubusercontent.com/dandi/schema/master/releases/0.6.3/context.json',
# ...

# %%
#INSTALL PREREQUISITES [IN JUPYTER NOTEBOOK]
#!{sys.executable} -m pip install nwbwidgets


from pynwb import NWBHDF5IO
from nwbwidgets import nwb2widget   #not working as of 22-JUN-2023

# io = NWBHDF5IO('path/to/file.nwb', mode='r')
# nwb = io.read()
#
# nwb2widget(nwb)

#
#
# import pynwb
#
# from pynwb import NWBHDF5IO
# from nwbwidgets import nwb2widget
# import requests

# from nwbwidgets import Panel
# Panel()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 0>()
#       1 #INSTALL PREREQUISITES [IN JUPYTER NOTEBOOK]
#       2 #!{sys.executable} -m pip install nwbwidgets
#       5 from pynwb import NWBHDF5IO
# ----> 6 from nwbwidgets import nwb2widget
#
# File D:\venv\nwb\Lib\site-packages\nwbwidgets\__init__.py:3, in <module>
#       1 import plotly.io as pio
# ----> 3 from .view import nwb2widget, default_neurodata_vis_spec
#       5 # from .ephys_viz_interface import ephys_viz_neurodata_vis_spec
#       7 from .version import version as __version__
#
# File D:\venv\nwb\Lib\site-packages\nwbwidgets\view.py:12, in <module>
#       9 from ndx_icephys_meta.icephys import SweepSequences
#      10 from ndx_spectrum import Spectrum
# ---> 12 from nwbwidgets import (
#      13     behavior,
#      14     misc,
#      15     base,
#      16     ecephys,
# ...
